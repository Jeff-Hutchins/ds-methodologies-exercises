# %% [markdown]
# Time series + EMA
#
# Discover users who are accessing our curriculum pages way beyond the end of their codeup time. What would the dataframe look like? Use time series method for detecting anomalies, like exponential moving average with %b.
#
# Bonus:
#
# Can you label students who are viewing both the web dev and data science curriculum? Can you label students by the program they are in? Can you label users by student vs. staff? What are Zach, Maggie, David, and Ryan's ids?

# %%
import numpy as np
import pandas as pd
import math
from sklearn import metrics

from scipy.stats import entropy

import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Zach or Ryan = 11
#
# David = 404

# %%
# Davids Content
# df[df.id == 404]

# %%
# Zach or Ryan
# df[df.id == 11]

# %%
df = pd.read_csv('anonymized-curriculum-access.txt', 
                 header=None,
                 sep=" ",
                 parse_dates=True
                 )
df.head()
# Out:
#             0         1                                    2  3     4  \
# 0  2018-01-26  09:55:03                                    /  1   8.0
# 1  2018-01-26  09:56:02                              java-ii  1   8.0
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming  1   8.0
# 3  2018-01-26  09:56:06   slides/object_oriented_programming  1   8.0
# 4  2018-01-26  09:56:24            javascript-i/conditionals  2  22.0
#
#               5
# 0  97.105.19.61
# 1  97.105.19.61
# 2  97.105.19.61
# 3  97.105.19.61
# 4  97.105.19.61

# %%
df.isnull().sum()
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4    26754
# 5        0
# dtype: int64

# %%
df[4].value_counts()
# Out:
# 29.0    35969
# 24.0    35039
# 33.0    34433
# 22.0    28875
# 23.0    28056
# 32.0    26801
# 26.0    26760
# 25.0    25233
# 31.0    22665
# 28.0    20677
# 27.0    20198
# 34.0    15519
# 51.0    10835
# 14.0     9069
# 1.0      8877
# 21.0     7181
# 17.0     3792
# 52.0     2896
# 13.0     2610
# 8.0      1671
# 18.0     1603
# 19.0     1142
# 16.0      740
# 15.0      691
# 7.0       461
# 12.0      270
# 11.0      204
# 2.0        93
# 6.0        72
# 9.0         5
# 4.0         4
# Name: 4, dtype: int64

# %%
df['timestamp'] = (df[0] + ' ') + df[1]

df = df.drop(columns=[0, 1])

# %%
df.timestamp = pd.to_datetime(df.timestamp)

# %%
df.dtypes
# Out:
# 2                    object
# 3                     int64
# 4                   float64
# 5                    object
# timestamp    datetime64[ns]
# dtype: object

# %%
df.set_index('timestamp', inplace=True)

# %%
df['2019-03']
# Out:
#                                                            2    3     4  \
# timestamp
# 2019-03-01 00:32:45                                        /  353   NaN
# 2019-03-01 00:33:23             4.2_data_types_and_variables  353   NaN
# 2019-03-01 00:33:50             4.2_data_types_and_variables  353   NaN
# 2019-03-01 00:49:06                         4.1_introduction  353   NaN
# 2019-03-01 00:50:00                                      git  353   NaN
# 2019-03-01 00:50:10                                      git  353   NaN
# 2019-03-01 03:04:35   spring/fundamentals/form-model-binding  308  27.0
# 2019-03-01 08:36:35                                        /  343  29.0
# 2019-03-01 08:36:40                                      toc  343  29.0
# 2019-03-01 08:36:45                     javascript-i/objects  343  29.0
# 2019-03-01 08:50:28                            4.4_functions  248  28.0
# 2019-03-01 08:50:30                   4.3_control_structures  248  28.0
# ...

# %%
df.columns = ['webpage', 'id', 'cohort', 'ip']

# %%
df[df.cohort.isnull()]
# Out:
#                                                                webpage   id  \
# timestamp
# 2018-01-26 16:46:16                                                  /   48
# 2018-01-26 16:46:24              spring/extra-features/form-validation   48
# 2018-01-26 17:54:24                                                  /   48
# 2018-01-26 18:32:03                                                  /   48
# 2018-01-26 18:32:17                          mysql/relationships/joins   48
# 2018-01-26 18:32:33                                       mysql/tables   48
# 2018-01-26 18:32:37                                    mysql/databases   48
# 2018-01-26 18:32:43                                mysql/relationships   48
# 2018-01-26 18:32:47                          mysql/relationships/joins   48
# 2018-01-26 18:33:07                                mysql/relationships   48
# 2018-01-26 18:33:13                              mysql/database-design   48
# ...

# %%
df.cohort.value_counts()
# Out:
# 29.0    35969
# 24.0    35039
# 33.0    34433
# 22.0    28875
# 23.0    28056
# 32.0    26801
# 26.0    26760
# 25.0    25233
# 31.0    22665
# 28.0    20677
# 27.0    20198
# 34.0    15519
# 51.0    10835
# 14.0     9069
# 1.0      8877
# 21.0     7181
# 17.0     3792
# 52.0     2896
# 13.0     2610
# 8.0      1671
# 18.0     1603
# 19.0     1142
# 16.0      740
# 15.0      691
# 7.0       461
# 12.0      270
# 11.0      204
# 2.0        93
# 6.0        72
# 9.0         5
# 4.0         4
# Name: cohort, dtype: int64

# %% [markdown]
# We are cohort 34
#
# Number of uniques are 22, we had 21, so someone must've been added.  Cody??

# %%
df[df.cohort == 34].nunique()
# Out:
# webpage    252
# id          22
# cohort       1
# ip          92
# dtype: int64

# %%
df[df.cohort == 34][['id', 'ip']].ip.unique()
# Out:
# array(['97.105.19.58', '67.11.115.125', '172.8.173.224', '173.175.104.33',
#        '12.197.196.242', '71.42.196.114', '70.226.109.182',
#        '172.124.64.127', '216.110.79.11', '108.174.80.231',
#        '174.207.21.10', '65.43.118.72', '67.10.174.4', '136.50.49.145',
#        '67.11.120.157', '173.149.142.35', '208.54.86.133',
#        '70.226.110.58', '166.251.109.48', '99.98.32.97', '130.45.33.133',
#        '75.1.166.163', '70.117.31.136', '72.181.117.73', '66.69.81.250',
#        '76.211.181.33', '67.11.82.11', '70.123.225.30', '173.127.7.219',
#        '173.127.93.78', '136.50.54.2', '71.78.109.210', '99.158.246.101',
#        '107.132.82.186', '173.173.105.24', '172.56.7.16', '96.8.151.49',
#        '192.171.117.210', '70.123.161.21', '64.108.32.10', '172.56.7.112',
#        '107.77.221.19', '166.251.109.196', '172.58.103.191',
#        '71.41.242.68', '172.14.106.31', '166.251.101.233',
#        '72.181.113.170', '98.6.147.203', '209.6.64.234', '67.11.138.10',
# ...

# %%
df['2019-05-06']
# Out:
#                                                      webpage   id  cohort  \
# timestamp
# 2019-05-06 00:01:57                                        /  353     NaN
# 2019-05-06 00:02:58                             10.4_Prepare  353     NaN
# 2019-05-06 00:03:38                             10_Exercises  353     NaN
# 2019-05-06 00:35:27                                        /  327    29.0
# 2019-05-06 00:35:38                                        /  327    29.0
# 2019-05-06 00:35:54                   3.1-mysql-introduction  327    29.0
# 2019-05-06 00:36:11                             4.0_overview  327    29.0
# 2019-05-06 00:36:37            4.6.4_introduction_to_seaborn  327    29.0
# 2019-05-06 00:37:39                                      toc  327    29.0
# 2019-05-06 00:37:52     appendix/extra-challenges/mars-rover  327    29.0
# 2019-05-06 00:38:42      appendix/extra-challenges/sales-tax  327    29.0
# ...

# %% [markdown]
# column 4 has values of 1-52.  Although weeks doesn't make sense, so must be something else

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-26 09:55:03', '2018-01-26 09:56:02',
#                '2018-01-26 09:56:05', '2018-01-26 09:56:06',
#                '2018-01-26 09:56:24', '2018-01-26 09:56:41',
#                '2018-01-26 09:56:46', '2018-01-26 09:56:48',
#                '2018-01-26 09:56:59', '2018-01-26 09:58:26',
#                ...
#                '2019-11-19 10:05:00', '2019-11-19 10:05:53',
#                '2019-11-19 10:06:13', '2019-11-19 10:06:21',
#                '2019-11-19 10:06:26', '2019-11-19 10:06:28',
#                '2019-11-19 10:06:50', '2019-11-19 10:07:03',
#                '2019-11-19 10:07:07', '2019-11-19 10:07:45'],
#               dtype='datetime64[ns]', name='timestamp', length=399195, freq=None)

# %%
df.cohort.value_counts().index.max()
# Out:
# 52.0

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-26 09:55:03', '2018-01-26 09:56:02',
#                '2018-01-26 09:56:05', '2018-01-26 09:56:06',
#                '2018-01-26 09:56:24', '2018-01-26 09:56:41',
#                '2018-01-26 09:56:46', '2018-01-26 09:56:48',
#                '2018-01-26 09:56:59', '2018-01-26 09:58:26',
#                ...
#                '2019-11-19 10:05:00', '2019-11-19 10:05:53',
#                '2019-11-19 10:06:13', '2019-11-19 10:06:21',
#                '2019-11-19 10:06:26', '2019-11-19 10:06:28',
#                '2019-11-19 10:06:50', '2019-11-19 10:07:03',
#                '2019-11-19 10:07:07', '2019-11-19 10:07:45'],
#               dtype='datetime64[ns]', name='timestamp', length=399195, freq=None)

# %%
df.id.head()
# Out:
# timestamp
# 2018-01-26 09:55:03    1
# 2018-01-26 09:56:02    1
# 2018-01-26 09:56:05    1
# 2018-01-26 09:56:06    1
# 2018-01-26 09:56:24    2
# Name: id, dtype: int64

# %%
df['id'].value_counts().head(50)
# Out:
# 53     8236
# 64     8008
# 11     8004
# 344    5279
# 1      4266
# 314    3233
# 423    2995
# 323    2846
# 354    2821
# 211    2625
# 418    2598
# 127    2563
# 410    2398
# 277    2367
# 347    2318
# 325    2248
# 363    2237
# 433    2217
# 337    2183
# 186    2180
# 274    2136
# 315    2130
# 416    2103
# 368    2063
# 304    2061
# 272    2008
# 197    1993
# 275    1900
# 264    1898
# 269    1894
# 263    1889
# 460    1885
# 324    1876
# 419    1822
# 248    1815
# 25     1809
# 7      1803
# 393    1798
# 302    1791
# 438    1778
# 408    1772
# 334    1771
# 195    1759
# 190    1747
# 453    1746
# 234    1743
# 439    1735
# 5      1701
# 330    1698
# 407    1694
# Name: id, dtype: int64

# %%
df.webpage.value_counts()
# Out:
# /                                                                            20564
# javascript-i                                                                  8140
# search/search_index.json                                                      7005
# toc                                                                           6679
# html-css                                                                      6143
# java-iii                                                                      6003
# spring                                                                        5761
# jquery                                                                        5501
# java-ii                                                                       5386
# mysql                                                                         5103
# java-i                                                                        5039
# ...

# %% [markdown]
# IDs to look at:  27, 42, 38, 15

# %%
df[df.id == 5]
# Out:
#                                                                webpage  id  \
# timestamp
# 2018-01-26 09:59:22                           mkdocs/search_index.json   5
# 2018-01-26 11:03:54  appendix/further-reading/javascript/hoisting.html   5
# 2018-01-26 11:04:03  appendix/further-reading/javascript/hoisting.html   5
# 2018-01-26 11:46:03  appendix/further-reading/javascript/hoisting.html   5
# 2018-01-26 11:46:09  appendix/further-reading/javascript/hoisting.html   5
# 2018-01-26 11:46:15  appendix/further-reading/javascript/hoisting.html   5
# 2018-01-26 11:46:26  appendix/further-reading/javascript/hoisting.html   5
# 2018-01-26 11:46:40                           mkdocs/search_index.json   5
# 2018-01-26 11:46:54       appendix/further-reading/javascript/hoisting   5
# 2018-01-26 11:47:38                  javascript-i/javascript-with-html   5
# 2018-01-26 11:47:44                             javascript-i/functions   5
# ...

# %%
df[df.webpage.str.contains('fundamentals')]
# Out:
#                                                          webpage   id  cohort  \
# timestamp
# 2018-01-26 11:40:40  spring/fundamentals/security/authentication   27    21.0
# 2018-01-26 11:58:56            spring/fundamentals/relationships   27    21.0
# 2018-01-26 11:59:13             spring/fundamentals/repositories   27    21.0
# 2018-01-26 12:18:32            spring/fundamentals/relationships   27    21.0
# 2018-01-26 15:26:44              spring/fundamentals/controllers   42    21.0
# 2018-01-26 15:26:52                    spring/fundamentals/views   42    21.0
# 2018-01-26 15:26:54              spring/fundamentals/controllers   42    21.0
# 2018-01-26 15:26:57              spring/fundamentals/controllers   42    21.0
# 2018-01-26 15:27:02                    spring/fundamentals/views   42    21.0
# 2018-01-26 15:27:38                 spring/fundamentals/services   42    21.0
# 2018-01-26 15:27:44       spring/fundamentals/form-model-binding   42    21.0
# ...

# %% [markdown]
# ### Finding Ada

# %%
df_temp = df['2019-02':'2019-07']

# %%
df_temp[df_temp.cohort.isnull()]
# Out:
#                                                       webpage   id  cohort  \
# timestamp
# 2019-02-01 18:05:04                                         /   88     NaN
# 2019-02-02 14:59:36                                         /   88     NaN
# 2019-02-02 18:46:42                                       toc   88     NaN
# 2019-02-02 18:46:43                                  html-css   88     NaN
# 2019-02-02 18:46:56                     html-css/introduction   88     NaN
# 2019-02-02 18:53:23                                  html-css   88     NaN
# 2019-02-02 18:53:26                     html-css/introduction   88     NaN
# 2019-02-02 18:53:27                         html-css/elements   88     NaN
# 2019-02-02 18:54:30                     html-css/introduction   88     NaN
# 2019-02-04 16:22:20                                         /  349     NaN
# 2019-02-04 16:22:36                                         /  350     NaN
# ...

# %%
df_temp[df_temp.webpage.str.contains('anomaly')]
# Out:
#                                                                webpage   id  \
# timestamp
# 2019-07-02 11:44:01              9-anomaly-detection/isolation-forests  349
# 2019-07-02 14:44:29              9-anomaly-detection/isolation-forests  349
# 2019-07-08 10:33:50                     9-anomaly-detection/1-overview    1
# 2019-07-08 10:33:50   9-anomaly-detection/AnomalyDetectionCartoon.jpeg    1
# 2019-07-08 10:35:57  9-anomaly-detection/2-detecting-through-probab...    1
# 2019-07-08 10:39:28  9-anomaly-detection/3-detecting-timeseries-ano...    1
# 2019-07-08 10:41:38    9-anomaly-detection/4-detecting-with-clustering    1
# 2019-07-08 10:42:35                      9-anomaly-detection/exercises    1
# 2019-07-08 10:43:31  9-anomaly-detection/2-detecting-through-probab...    1
# 2019-07-08 10:43:45  9-anomaly-detection/3-detecting-timeseries-ano...    1
# 2019-07-08 10:43:52    9-anomaly-detection/4-detecting-with-clustering    1
# ...

# %% [markdown]
# Why do the numbers increase as cohorts go up?

# %%
df[df.cohort == 4]
# Out:
#                                        webpage  id  cohort             ip
# timestamp
# 2018-02-04 11:21:38                          /  85     4.0  66.42.139.162
# 2018-02-04 11:23:27   mkdocs/search_index.json  85     4.0  66.42.139.162
# 2018-02-04 11:24:05          prework/databases  85     4.0  66.42.139.162
# 2018-02-04 11:24:56  prework/versioning/github  85     4.0  66.42.139.162

# %%
list(df.cohort.value_counts().index)
# Out:
# [29.0,
#  24.0,
#  33.0,
#  22.0,
#  23.0,
#  32.0,
#  26.0,
#  25.0,
#  31.0,
#  28.0,
#  27.0,
#  34.0,
#  51.0,
#  14.0,
#  1.0,
#  21.0,
#  17.0,
#  52.0,
#  13.0,
#  8.0,
#  18.0,
#  19.0,
#  16.0,
#  15.0,
#  7.0,
#  12.0,
#  11.0,
#  2.0,
#  6.0,
#  9.0,
#  4.0]

# %%
df[df.cohort == 8]
# Out:
#                                                                webpage  id  \
# timestamp
# 2018-01-26 09:55:03                                                  /   1
# 2018-01-26 09:56:02                                            java-ii   1
# 2018-01-26 09:56:05                java-ii/object-oriented-programming   1
# 2018-01-26 09:56:06                 slides/object_oriented_programming   1
# 2018-01-26 10:40:15                             javascript-i/functions   1
# 2018-01-26 11:26:13                                             java-i   1
# 2018-01-26 11:43:17                           mkdocs/search_index.json   1
# 2018-01-27 07:49:25                                           teams/13   1
# 2018-01-29 11:41:51                          javascript-i/conditionals   1
# 2018-01-29 11:43:08                                 javascript-i/loops   1
# 2018-01-29 15:06:28                              mysql/database-design   1
# ...

# %%
len(df.cohort)
# Out:
# 399195

# %% [markdown]
# Below is what df.cohort.value_counts does under the hood

# %%
df.head()
# Out:
#                                                  webpage  id  cohort  \
# timestamp
# 2018-01-26 09:55:03                                    /   1     8.0
# 2018-01-26 09:56:02                              java-ii   1     8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming   1     8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming   1     8.0
# 2018-01-26 09:56:24            javascript-i/conditionals   2    22.0
#
#                                ip
# timestamp
# 2018-01-26 09:55:03  97.105.19.61
# 2018-01-26 09:56:02  97.105.19.61
# 2018-01-26 09:56:05  97.105.19.61
# 2018-01-26 09:56:06  97.105.19.61
# 2018-01-26 09:56:24  97.105.19.61

# %%
list(df.cohort.value_counts().index)
# Out:
# [29.0,
#  24.0,
#  33.0,
#  22.0,
#  23.0,
#  32.0,
#  26.0,
#  25.0,
#  31.0,
#  28.0,
#  27.0,
#  34.0,
#  51.0,
#  14.0,
#  1.0,
#  21.0,
#  17.0,
#  52.0,
#  13.0,
#  8.0,
#  18.0,
#  19.0,
#  16.0,
#  15.0,
#  7.0,
#  12.0,
#  11.0,
#  2.0,
#  6.0,
#  9.0,
#  4.0]

# %%
df[df.cohort == 34]
# Out:
#                                                       webpage   id  cohort  \
# timestamp
# 2019-08-20 09:39:58                                         /  466    34.0
# 2019-08-20 09:39:59                                         /  467    34.0
# 2019-08-20 09:39:59                                         /  468    34.0
# 2019-08-20 09:40:02                                         /  469    34.0
# 2019-08-20 09:40:08                                         /  470    34.0
# 2019-08-20 09:40:15                                         /  471    34.0
# 2019-08-20 09:40:15                                         /  472    34.0
# 2019-08-20 09:40:17                                         /  473    34.0
# 2019-08-20 09:40:18                                         /  474    34.0
# 2019-08-20 09:40:19                                         /  475    34.0
# 2019-08-20 09:40:23                                         /  476    34.0
# ...

# %%
for i in list(df.cohort.value_counts().index):
    print(len(df[df.cohort == i]))
# Out:
# 35969
# 35039
# 34433
# 28875
# 28056
# 26801
# 26760
# 25233
# 22665
# 20677
# 20198
# 15519
# 10835
# 9069
# 8877
# 7181
# 3792
# 2896
# 2610
# 1671
# 1603
# 1142
# 740
# 691
# 461
# 270
# 204
# 93
# 72
# 5
# 4

# %% [markdown]
# ## ID's of each cohort

# %%
df[df.cohort == 6].id.value_counts()
# Out:
# 283    59
# 405    13
# Name: id, dtype: int64
