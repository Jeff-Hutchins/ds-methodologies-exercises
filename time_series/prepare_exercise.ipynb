# %%
# %matplotlib inline

import pandas as pd
import acquire

df = acquire.get_all_data()
df.head
# Out:
# <bound method NDFrame.head of         item_id  sale_amount                      sale_date  sale_id  \
# 0             1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1
# 1             1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2
# 2             1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3
# 3             1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4
# 4             1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5
# 5             1         12.0  Sun, 06 Jan 2013 00:00:00 GMT        6
# 6             1         10.0  Mon, 07 Jan 2013 00:00:00 GMT        7
# 7             1          9.0  Tue, 08 Jan 2013 00:00:00 GMT        8
# 8             1         12.0  Wed, 09 Jan 2013 00:00:00 GMT        9
# 9             1          9.0  Thu, 10 Jan 2013 00:00:00 GMT       10
# 10            1          9.0  Fri, 11 Jan 2013 00:00:00 GMT       11
# 11            1          7.0  Sat, 12 Jan 2013 00:00:00 GMT       12
# ...

# %%
# df = pd.read_csv('sales_data.csv')

# %%
df.shape
# Out:
# (913000, 14)
